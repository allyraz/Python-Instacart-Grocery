# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\Azalia\Documents\Projects\Self-Study\CareerFoundry\Instacart Analysis"

# %%
# import ord_prod data
df_ord_prod = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_profileflags.pkl'))

# %%
df_ord_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   order_id                      int32
#  1   user_id                       int32
#  2   order_number                  int32
#  3   order_day_of_week             int32
#  4   order_hour_of_day             int32
#  5   days since_last_order         float32
#  6   NaN_Flag                      bool
#  7   product_id                    float32
#  8   add_to_cart_order             float32
#  9   reordered                     bool
#  10  product_name                  object
#  11  aisle_id                      int64
#  12  department_id                 int64
#  13  prices                        float64
#  14  _merge                        category
#  15  price_range_loc               object
#  16  busiest_day                   object
#  17  updated_busiest_day           object
# ...

# %%
# reducing memory: changing for datatypes
# changing data types using list
df_ord_prod.astype({'aisle_id':'int32','department_id':'int32','prices':'float32','ave_prices':'float32'})
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days since_last_order  NaN_Flag  product_id  \
# 0                         8                    NaN      True       196.0
# 1                         7                   15.0     False       196.0
# ...

# %%
df_ord_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   order_id                      int32
#  1   user_id                       int32
#  2   order_number                  int32
#  3   order_day_of_week             int32
#  4   order_hour_of_day             int32
#  5   days since_last_order         float32
#  6   NaN_Flag                      bool
#  7   product_id                    float32
#  8   add_to_cart_order             float32
#  9   reordered                     bool
#  10  product_name                  object
#  11  aisle_id                      int64
#  12  department_id                 int64
#  13  prices                        float64
#  14  _merge                        category
#  15  price_range_loc               object
#  16  busiest_day                   object
#  17  updated_busiest_day           object
# ...

# %%
df_ord_prod['aisle_id']=df_ord_prod['aisle_id'].astype('int32')

# %%
df_ord_prod['aisle_id'].dtype
# Out:
# dtype('int32')

# %%
df_ord_prod['department_id']=df_ord_prod['department_id'].astype('int32')

# %%
df_ord_prod['prices']=df_ord_prod['prices'].astype('float32')
df_ord_prod['ave_prices']=df_ord_prod['ave_prices'].astype('float32')

# %%
df_ord_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 25 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   order_id                      int32
#  1   user_id                       int32
#  2   order_number                  int32
#  3   order_day_of_week             int32
#  4   order_hour_of_day             int32
#  5   days since_last_order         float32
#  6   NaN_Flag                      bool
#  7   product_id                    float32
#  8   add_to_cart_order             float32
#  9   reordered                     bool
#  10  product_name                  object
#  11  aisle_id                      int32
#  12  department_id                 int32
#  13  prices                        float32
#  14  _merge                        category
#  15  price_range_loc               object
#  16  busiest_day                   object
#  17  updated_busiest_day           object
# ...

# %%
df_ord_prod.to_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merge_profileflags2.pkl'))
