# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\Azalia\Documents\Projects\Self-Study\CareerFoundry\Instacart Analysis"

# %%
# import ord_prod data
df_ord_prod_cust = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ord_prod_cust.pkl'))

# %% [markdown]
# df_ord_prod_cust['frequency_flag'].value_counts()

# %%
df_ord_prod_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 34 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   order_id                      int32
#  1   user_id                       int32
#  2   order_number                  int32
#  3   order_day_of_week             int32
#  4   order_hour_of_day             int32
#  5   days_since_last_order         float32
#  6   NaN_Flag                      bool
#  7   product_id                    float32
#  8   add_to_cart_order             float32
#  9   reordered                     bool
#  10  product_name                  object
#  11  aisle_id                      int32
#  12  department_id                 int32
#  13  prices                        float32
#  14  _merge                        category
#  15  price_range_loc               object
#  16  busiest_day                   object
#  17  updated_busiest_day           object
# ...

# %%
df_ord_prod_cust.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07       3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01       2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01       2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00       1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01       3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01       6.000000e+00
#
#        order_hour_of_day  days_since_last_order    product_id  \
# count       3.240486e+07           3.032876e+07  3.240486e+07
# mean        1.342515e+01           1.024203e+01  2.398573e+04
# std         4.246380e+00           8.495049e+00  1.373331e+04
# min         0.000000e+00           0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# # reducing memory: changing for datatypes
# # changing data types using list
# df_ord_prod_cust.astype({'order_number':'int8', 'order_day_of_week':'int8','order_hour_of_day':'int8', 'aisle_id':'int8','department_id':'int8','prices':'float32','ave_prices':'float32'})

# %%
#df_ord_prod_cust['order_id']=df_ord_prod_cust['order_id'].astype('int32')
df_ord_prod_cust['user_id']=df_ord_prod_cust['user_id'].astype('str')
df_ord_prod_cust['order_number']=df_ord_prod_cust['order_number'].astype('int8')
df_ord_prod_cust['order_day_of_week']=df_ord_prod_cust['order_day_of_week'].astype('int8')

# %%
df_ord_prod_cust['order_hour_of_day']=df_ord_prod_cust['order_hour_of_day'].astype('int8')
df_ord_prod_cust['days_since_last_order']=df_ord_prod_cust['days_since_last_order'].astype('float16')
df_ord_prod_cust['aisle_id']=df_ord_prod_cust['aisle_id'].astype('int16')
df_ord_prod_cust['department_id']=df_ord_prod_cust['department_id'].astype('int8')

# %%
df_ord_prod_cust['product_id']=df_ord_prod_cust['product_id'].astype('float16')
df_ord_prod_cust['add_to_cart_order']=df_ord_prod_cust['add_to_cart_order'].astype('float16')
#check df_ord_prod_cust['prices']=df_ord_prod_cust['prices'].astype('float16')
df_ord_prod_cust['ave_prices']=df_ord_prod_cust['ave_prices'].astype('float16')

# %%
df_ord_prod_cust['price_range_loc']=df_ord_prod_cust['price_range_loc'].astype('category')
df_ord_prod_cust['busiest_day']=df_ord_prod_cust['busiest_day'].astype('category')
df_ord_prod_cust['updated_busiest_day']=df_ord_prod_cust['updated_busiest_day'].astype('category')
df_ord_prod_cust['busiest_period_of_day']=df_ord_prod_cust['busiest_period_of_day'].astype('category')
df_ord_prod_cust['loyalty_flag']=df_ord_prod_cust['loyalty_flag'].astype('category')
df_ord_prod_cust['spending_flag']=df_ord_prod_cust['spending_flag'].astype('category')
df_ord_prod_cust['frequency_flag']=df_ord_prod_cust['frequency_flag'].astype('category')

# %%
df_ord_prod_cust['max_order']=df_ord_prod_cust['max_order'].astype('int8')
df_ord_prod_cust['median_days_since_last_order']=df_ord_prod_cust['median_days_since_last_order'].astype('float16')

# %%
df_ord_prod_cust['gender']=df_ord_prod_cust['gender'].astype('category')
df_ord_prod_cust['age']=df_ord_prod_cust['age'].astype('int8')
df_ord_prod_cust['marital_status']=df_ord_prod_cust['marital_status'].astype('category')
df_ord_prod_cust['num_dependents']=df_ord_prod_cust['num_dependents'].astype('int8')
#df_ord_prod_cust['income']=df_ord_prod_cust['income'].astype('int16')

# %%
df_ord_prod_cust.describe()
# Out:
#            order_id  order_number  order_day_of_week  order_hour_of_day  \
# count  3.240486e+07  3.240486e+07       3.240486e+07       3.240486e+07
# mean   1.710745e+06  1.714230e+01       2.738867e+00       1.342515e+01
# std    9.872988e+05  1.753532e+01       2.090077e+00       4.246380e+00
# min    2.000000e+00  1.000000e+00       0.000000e+00       0.000000e+00
# 25%    8.559470e+05  5.000000e+00       1.000000e+00       1.000000e+01
# 50%    1.711049e+06  1.100000e+01       3.000000e+00       1.300000e+01
# 75%    2.565499e+06  2.400000e+01       5.000000e+00       1.600000e+01
# max    3.421083e+06  9.900000e+01       6.000000e+00       2.300000e+01
#
#        days_since_last_order  product_id  add_to_cart_order      aisle_id  \
# count             30328763.0  32404859.0         32404859.0  3.240486e+07
# mean                     NaN         NaN                NaN  7.119612e+01
# std                      0.0         NaN                0.0  3.821139e+01
# ...

# %%
df_ord_prod_cust.head(10)
# Out:
#    order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                  2                  8
# 1   2398795       1             2                  3                  7
# 2    473747       1             3                  3                 12
# 3   2254736       1             4                  4                  7
# 4    431534       1             5                  4                 15
# 5   3367565       1             6                  2                  7
# 6    550135       1             7                  1                  9
# 7   3108588       1             8                  1                 14
# 8   2295261       1             9                  1                 16
# 9   2550362       1            10                  4                  8
#
#    days_since_last_order  NaN_Flag  product_id  add_to_cart_order  reordered  \
# 0                    NaN      True       196.0                1.0      False
# ...

# %%
df_ord_prod_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 34 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   order_id                      int32
#  1   user_id                       object
#  2   order_number                  int8
#  3   order_day_of_week             int8
#  4   order_hour_of_day             int8
#  5   days_since_last_order         float16
#  6   NaN_Flag                      bool
#  7   product_id                    float16
#  8   add_to_cart_order             float16
#  9   reordered                     bool
#  10  product_name                  object
#  11  aisle_id                      int16
#  12  department_id                 int8
#  13  prices                        float32
#  14  _merge                        category
#  15  price_range_loc               category
#  16  busiest_day                   category
#  17  updated_busiest_day           category
# ...

# %%
df_ord_prod_cust.to_pickle(os.path.join(path,'02 Data','Prepared Data','ord_prod_cust2.pkl'))
